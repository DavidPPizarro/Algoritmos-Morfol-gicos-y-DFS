# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
imagen = cv2.imread('komo.jpg', cv2.IMREAD_GRAYSCALE)
imagen_rgb = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)

if imagen_rgb is None:
    print("Error: No se pudo cargar la imagen.")
else:
    print("Matriz de la imagen en RGB:")
    print(imagen_rgb) 
    
    # Mostrar una parte de la matriz (por si es muy grande)
    print("\nMatriz (primeros 10x10 píxeles en RGB):")
    print(imagen_rgb[:100000, :100000, :])  # Muestra una sección de la matriz (R,G,B)

    # Mostrar la imagen
    plt.imshow(imagen_rgb)
    plt.title('Imagen en RGB')
    plt.axis('off')
    plt.show()
# Out:
# Matriz de la imagen en RGB:
# [[[ 75  75  75]
#   [ 90  90  90]
#   [119 119 119]
#   ...
#   [ 86  86  86]
#   [ 88  88  88]
#   [ 86  86  86]]
#
#  [[ 49  49  49]
#   [ 33  33  33]
#   [ 65  65  65]
#   ...
#   [ 72  72  72]
#   [ 52  52  52]
#   [ 38  38  38]]
#
#  [[113 113 113]
#   [ 50  50  50]
#   [ 16  16  16]
#   ...
#   [ 41  41  41]
#   [ 43  43  43]
#   [ 69  69  69]]
#
#  ...
#
#  [[ 10  10  10]
#   [ 17  17  17]
#   [  1   1   1]
#   ...
#   [ 95  95  95]
#   [103 103 103]
#   [115 115 115]]
#
#  [[ 16  16  16]
#   [ 13  13  13]
#   [  3   3   3]
#   ...
#   [  2   2   2]
#   [ 26  26  26]
#   [111 111 111]]
#
#  [[  4   4   4]
#   [  3   3   3]
#   [ 10  10  10]
#   ...
#   [ 30  30  30]
#   [ 16  16  16]
#   [ 68  68  68]]]
#
# Matriz (primeros 10x10 píxeles en RGB):
# [[[ 75  75  75]
#   [ 90  90  90]
#   [119 119 119]
#   ...
#   [ 86  86  86]
#   [ 88  88  88]
#   [ 86  86  86]]
#
#  [[ 49  49  49]
#   [ 33  33  33]
#   [ 65  65  65]
#   ...
#   [ 72  72  72]
# ...

# %%
kernel = np.ones((5,5), np.uint8)

erosion = cv2.erode(imagen_rgb, kernel, iterations=1)

cv2.imshow('Original', imagen)
cv2.imshow('Erosion', erosion)

cv2.waitKey(0)
cv2.destroyAllWindows()
